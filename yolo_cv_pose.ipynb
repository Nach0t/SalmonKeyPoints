# %% [markdown]
# # Cross-Validation y Predicción con YOLO11 Pose

# %%
from ultralytics import YOLO
import cv2
import os
import yaml
import numpy as np

MODEL_NAME = "yolo11x-pose.pt" 
K_FOLDS = 5
IMG_SIZE = 640
BATCH_SIZE = 6

BASE_IMG_DIR = "images"
BASE_LBL_DIR = "labels"
TEST_DIR = "images/test"

OUT_LABEL_TEST = "labels/test_pred"
OUT_IMAGE_TEST = "predictions_test"

os.makedirs(OUT_LABEL_TEST, exist_ok=True)
os.makedirs(OUT_IMAGE_TEST, exist_ok=True)

# %% [markdown]
# ## Función para generar YAML dinámico
# Cada fold crea su propio archivo YAML con rutas absolutas.

# %%
def crear_yaml_fold(fold_idx, train_folds, val_fold):
    cwd = os.getcwd()

    train_paths = [os.path.join(cwd, BASE_IMG_DIR, f) for f in train_folds]
    val_path = os.path.join(cwd, BASE_IMG_DIR, val_fold)

    yaml_data = {
        'path': cwd,
        'train': train_paths,
        'val': val_path,
        'names': {0: 'salmon'},
        'kpt_shape': [4, 3]
    }

    yaml_filename = f"data_fold_{fold_idx}.yaml"
    with open(yaml_filename, 'w') as f:
        yaml.dump(yaml_data, f, sort_keys=False)

    return yaml_filename

# %% [markdown]
# ## Cross Validation
# Se entrena un modelo distinto por cada fold y se selecciona el mejor a partir del mAP50-95.

# %%
def cross_validation():
    print("\nINICIANDO CROSS-VALIDATION...\n")

    fold_metrics = []
    best_map = 0
    best_model_path = ""

    all_folds = [f"fold{i}" for i in range(1, K_FOLDS + 1)]

    for i in range(K_FOLDS):
        current_fold_idx = i + 1

        val_fold = all_folds[i]
        train_folds = [f for j, f in enumerate(all_folds) if j != i]

        print(f"\n===== FOLD {current_fold_idx}/{K_FOLDS} =====")
        print(f"Train: {train_folds}")
        print(f"Val:   {val_fold}\n")

        yaml_file = crear_yaml_fold(current_fold_idx, train_folds, val_fold)

        model = YOLO(MODEL_NAME)

        project_name = "runs/cv_pose"
        run_name = f"fold_{current_fold_idx}"

        model.train(
            data=yaml_file,
            imgsz=IMG_SIZE,
            epochs=20,
            batch=BATCH_SIZE,
            device=0,
            project=project_name,
            name=run_name,
            exist_ok=True,
            plots=True,
            verbose=False
        )

        metrics = model.val()
        map50_95 = metrics.pose.map

        print(f"Resultados Fold {current_fold_idx}: mAP50-95 = {map50_95:.4f}")
        fold_metrics.append(map50_95)

        if map50_95 > best_map:
            best_map = map50_95
            best_model_path = os.path.join(project_name, run_name, "weights", "best.pt")

    print("\nRESULTADOS CROSS-VALIDATION")
    for i, m in enumerate(fold_metrics):
        print(f"Fold {i+1}: {m:.4f}")

    print("--------------------------")
    print(f"PROMEDIO mAP: {np.mean(fold_metrics):.4f}")
    print(f"MEJOR MODELO: {best_model_path}")

    return best_model_path

# %% [markdown]
# ## Predicción en conjunto de test
# Se generan etiquetas automáticas y una visualización por cada imagen.

# %%
def predecir_test(model_path):
    print(f"\nGENERANDO ETIQUETAS PARA TEST ({TEST_DIR})...\n")

    if not os.path.exists(model_path):
        print("Error: No se encuentra el mejor modelo.")
        return

    model = YOLO(model_path)
    imgs = [f for f in os.listdir(TEST_DIR) if f.lower().endswith((".jpg", ".png", ".jpeg"))]

    print(f"Procesando {len(imgs)} imágenes de test...")

    for i, name in enumerate(imgs):
        img_path = os.path.join(TEST_DIR, name)

        results = model(img_path, device=0, conf=0.25, verbose=False)[0]

        if results.keypoints is None:
            continue

        kpts_norm = results.keypoints.xyn.cpu().numpy()
        if len(kpts_norm) == 0:
            continue

        txt_path = os.path.join(OUT_LABEL_TEST, name.rsplit(".", 1)[0] + ".txt")
        with open(txt_path, "w") as f:
            for kpts in kpts_norm:
                linea = "0 0.5 0.5 1.0 1.0 "
                for kx, ky in kpts:
                    vis = 2 if (kx > 0 or ky > 0) else 0
                    linea += f"{kx:.6f} {ky:.6f} {vis} "
                f.write(linea.strip() + "\n")

        img = cv2.imread(img_path)
        if img is not None:
            kpts_abs = results.keypoints.xy.cpu().numpy()
            for person in kpts_abs:
                for x, y in person:
                    if x == 0 and y == 0:
                        continue
                    cv2.circle(img, (int(x), int(y)), 4, (0, 255, 0), -1)
            cv2.imwrite(os.path.join(OUT_IMAGE_TEST, f"pred_{name}"), img)

        if i % 10 == 0:
            print(f"Progreso test: {i}/{len(imgs)}...")

    print("\nProceso completado.")
    print(f"Etiquetas TEST generadas en: {OUT_LABEL_TEST}")

# %% [markdown]
# ## Ejecutar Cross Validation y Predicción Final

# %%
mejor_modelo = cross_validation()
predecir_test(mejor_modelo)
# Out:
# INICIANDO CROSS-VALIDATION...
#
#
# ===== FOLD 1/5 =====
# Train: ['fold2', 'fold3', 'fold4', 'fold5']
# Val:   fold1
#
# New https://pypi.org/project/ultralytics/8.3.233 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221  Python-3.12.6 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=6, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data_fold_1.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11x-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=fold_1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/cv_pose, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[4, 3]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   5059063  ultralytics.nn.modules.head.Pose             [1, [4, 3], [384, 768, 768]]
# YOLO11x-pose summary: 372 layers, 58,787,287 parameters, 58,787,271 gradients, 203.8 GFLOPs
#
# Transferred 1051/1057 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.20.1 ms, read: 328.299.0 MB/s, size: 150.6 KB)
# train: Scanning C:\Users\usuario\Desktop\salmons_pose_project\labels\fold2... 885 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━
torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# YOLO11x-pose summary (fused): 199 layers, 58,739,959 parameters, 0 gradients, 202.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 6.2it/s 3.1s0.1s
#                    all        222        222          1          1      0.995      0.995          1          1      0.995      0.983
# Speed: 0.2ms preprocess, 6.2ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_1
# Ultralytics 8.3.221  Python-3.12.6 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# YOLO11x-pose summary (fused): 199 layers, 58,739,959 parameters, 0 gradients, 202.7 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 1436.9576.6 MB/s, size: 153.9 KB)
# val: Scanning C:\Users\usuario\Desktop\salmons_pose_project\labels\fold1.cache... 222 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 222/222 110.9Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.3it/s 4.2s0.2s
#                    all        222        222          1          1      0.995      0.995          1          1      0.995      0.981
# Speed: 1.7ms preprocess, 10.6ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to C:\Users\usuario\Desktop\salmons_pose_project\runs\pose\val6
# Resultados Fold 1: mAP50-95 = 0.9813
#
# ===== FOLD 2/5 =====
# Train: ['fold1', 'fold3', 'fold4', 'fold5']
# Val:   fold2
#
# New https://pypi.org/project/ultralytics/8.3.233 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221  Python-3.12.6 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=6, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data_fold_2.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11x-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=fold_2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/cv_pose, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[4, 3]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   5059063  ultralytics.nn.modules.head.Pose             [1, [4, 3], [384, 768, 768]]
# YOLO11x-pose summary: 372 layers, 58,787,287 parameters, 58,787,271 gradients, 203.8 GFLOPs
#
# Transferred 1051/1057 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.20.1 ms, read: 477.5447.6 MB/s, size: 118.2 KB)
# train: Scanning C:\Users\usuario\Desktop\salmons_pose_project\labels\fold1... 885 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 885/885 2.1Kit/s 0.4s0.0ss
# train: New cache created: C:\Users\usuario\Desktop\salmons_pose_project\labels\fold1.cache
# WARNING No 'flip_idx' array defined in data.yaml, disabling 'fliplr' and 'flipud' augmentations.
# val: Fast image access  (ping: 0.30.1 ms, read: 242.594.6 MB/s, size: 132.8 KB)
# val: Scanning C:\Users\usuario\Desktop\salmons_pose_project\labels\fold2... 222 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 222/222 973.7it/s 0.2s0.1s
# val: New cache created: C:\Users\usuario\Desktop\salmons_pose_project\labels\fold2.cache
# Plotting labels to C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_2\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups
1      0.995      0.984
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      6.46G     0.1213     0.2165    0.04798     0.1263     0.8662          3        640: 100% ━━━━━━━━━━━━ 148/148 4.5it/s 32.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.9it/s 2.4s0.1s
#                    all        222        222          1          1      0.995      0.995          1          1      0.995      0.986
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      6.72G     0.1041     0.1979    0.03934     0.1121     0.8511          3        640: 100% ━━━━━━━━━━━━ 148/148 4.6it/s 32.2s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.8it/s 2.4s0.1s
#                    all        222        222          1          1      0.995      0.995          1          1      0.995      0.988
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      6.72G     0.1007     0.1799    0.03871      0.108     0.8516          3        640: 100% ━━━━━━━━━━━━ 148/148 4.6it/s 32.4s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.8it/s 2.4s0.1s
#                    all        222        222          1          1      0.995      0.995          1          1      0.995      0.987
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      6.72G    0.09688     0.1784    0.03807     0.1034     0.8565          3        640: 100% ━━━━━━━━━━━━ 148/148 4.6it/s 32.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.8it/s 2.4s0.1s
#                    all        222        222          1          1      0.995      0.995          1          1      0.995      0.988
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      6.72G    0.07576     0.1714    0.03338    0.08564     0.8491          3        640: 100% ━━━━━━━━━━━━ 148/148 4.6it/s 32.4s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.5it/s 2.5s0.1s
#                    all        222        222          1          1      0.995      0.995          1          1      0.995      0.987
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      6.78G    0.06933     0.1588    0.03717    0.07823     0.8396          3        640: 100% ━━━━━━━━━━━━ 148/148 4.6it/s 32.2s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.9it/s 2.4s0.1s
#                    all        222        222          1          1      0.995      0.995          1          1      0.995      0.984
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      6.75G    0.06147     0.1561    0.04035    0.07147      0.839          3        640: 100% ━━━━━━━━━━━━ 148/148 4.6it/s 32.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.6it/s 2.5s0.1s
#                    all        222        222          1          1      0.995      0.995          1          1      0.995      0.989
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      6.58G    0.04976     0.1467    0.03501    0.06166      0.831          3        640: 100% ━━━━━━━━━━━━ 148/148 4.6it/s 32.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.9it/s 2.4s0.1s
#                    all        222        222          1          1      0.995      0.995          1          1      0.995      0.985
#
# 20 epochs completed in 0.212 hours.
# Optimizer stripped from C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_2\weights\last.pt, 118.2MB
# Optimizer stripped from C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_2\weights\best.pt, 118.2MB
#
# Validating C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_2\weights\best.pt...
# Ultralytics 8.3.221  Python-3.12.6 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# YOLO11x-pose summary (fused): 199 layers, 58,739,959 parameters, 0 gradients, 202.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 6.3it/s 3.0s0.1s
#                    all        222        222          1          1      0.995      0.995          1          1      0.995      0.989
# Speed: 0.3ms preprocess, 6.2ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_2
# Ultralytics 8.3.221  Python-3.12.6 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# YOLO11x-pose summary (fused): 199 layers, 58,739,959 parameters, 0 gradients, 202.7 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 1498.6333.6 MB/s, size: 156.7 KB)
# val: Scanning C:\Users\usuario\Desktop\salmons_pose_project\labels\fold2.cache... 222 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 222/222 222.0Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.3it/s 4.2s0.2s
#                    all        222        222          1          1      0.995      0.995          1          1      0.995      0.989
# Speed: 1.1ms preprocess, 10.7ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to C:\Users\usuario\Desktop\salmons_pose_project\runs\pose\val7
# Resultados Fold 2: mAP50-95 = 0.9893
#
# ===== FOLD 3/5 =====
# Train: ['fold1', 'fold2', 'fold4', 'fold5']
# Val:   fold3
#
# New https://pypi.org/project/ultralytics/8.3.233 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221  Python-3.12.6 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=6, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data_fold_3.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11x-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=fold_3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/cv_pose, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[4, 3]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   5059063  ultralytics.nn.modules.head.Pose             [1, [4, 3], [384, 768, 768]]
# YOLO11x-pose summary: 372 layers, 58,787,287 parameters, 58,787,271 gradients, 203.8 GFLOPs
#
# Transferred 1051/1057 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.1 ms, read: 885.8652.9 MB/s, size: 181.8 KB)
# train: Scanning C:\Users\usuario\Desktop\salmons_pose_project\labels\fold1... 886 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 886/886 2.3Kit/s 0.4s0.1ss
# train: New cache created: C:\Users\usuario\Desktop\salmons_pose_project\labels\fold1.cache
# WARNING No 'flip_idx' array defined in data.yaml, disabling 'fliplr' and 'flipud' augmentations.
# val: Fast image access  (ping: 0.10.0 ms, read: 266.6200.3 MB/s, size: 163.3 KB)
# val: Scanning C:\Users\usuario\Desktop\salmons_pose_project\labels\fold3.cache... 221 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 221/221 55.3Kit/s 0.0s
# Plotting labels to C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_3\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 173 weight(decay=0.0), 183 weight(decay=0.000515625), 182 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_3
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      6.82G     0.4606     0.9497      0.426      0.499      1.105         11        640: 100% ━━━━━━━━━━━━ 148/148 4.2it/s 35.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.6it/s 2.5s0.1s
#                    all        221        221      0.231       0.33      0.138      0.024      0.298      0.434      0.262     0.0774
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        2/20       6.7G     0.4545     0.6484     0.3119      0.447      1.056         14        640: 100% ━━━━━━━━━━━━ 148/148 4.5it/s 32.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.5it/s 2.5s0.1s
#                    all        221        221      0.994      0.995      0.995      0.949      0.994      0.995      0.995      0.758
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        3/20       6.5G     0.3657     0.5533     0.2964     0.3649     0.9891         13        640: 100% ━━━━━━━━━━━━ 148/148 4.6it/s 32.4s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.9it/s 2.4s0.1s
#                    all        221        221      0.987      0.998      0.995      0.923      0.987      0.998      0.995      0.909
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      6.75G     0.3212     0.4862     0.2576     0.3286     0.9565         12        640: 100% ━━━━━━━━━━━━ 148/148 4.6it/s 32.2s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.5it/s 2.5s0.1s
#                    all        221        221      0.998          1      0.995      0.995      0.998          1      0.995      0.869
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      6.75G     0.2857      0.435     0.2365     0.2917     0.9466         14        640: 100% ━━━━━━━━━━━━ 148/148 4.6it/s 32.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.7it/s 2.5s0.1s
# ...
#  23        [16, 19, 22]  1   5059063  ultralytics.nn.modules.head.Pose             [1, [4, 3], [384, 768, 768]]
# YOLO11x-pose summary: 372 layers, 58,787,287 parameters, 58,787,271 gradients, 203.8 GFLOPs
#
# Transferred 1051/1057 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 1192.6521.6 MB/s, size: 136.7 KB)
# train: Scanning C:\Users\usuario\Desktop\salmons_pose_project\labels\fold1... 886 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 886/886 2.2Kit/s 0.4s0.2ss
# train: New cache created: C:\Users\usuario\Desktop\salmons_pose_project\labels\fold1.cache
# WARNING No 'flip_idx' array defined in data.yaml, disabling 'fliplr' and 'flipud' augmentations.
# val: Fast image access  (ping: 0.10.0 ms, read: 506.9258.3 MB/s, size: 131.2 KB)
# val: Scanning C:\Users\usuario\Desktop\salmons_pose_project\labels\fold5.cache... 221 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 221/221 73.8Kit/s 0.0s
# Plotting labels to C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_5\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 173 weight(decay=0.0), 183 weight(decay=0.000515625), 182 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_5
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      6.38G     0.4759     0.9759     0.4322     0.5127      1.118         11        640: 100% ━━━━━━━━━━━━ 148/148 3.8it/s 38.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 6.9it/s 2.7s0.1s
#                    all        221        221       0.66      0.602      0.597      0.241      0.705      0.704      0.762      0.588
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      6.72G     0.4813     0.6631     0.3089     0.4616      1.076         14        640: 100% ━━━━━━━━━━━━ 148/148 4.2it/s 35.4s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 6.8it/s 2.8s0.1s
#                    all        221        221      0.963      0.946      0.985      0.853      0.963      0.946      0.985      0.833
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      6.72G     0.4199     0.5551     0.2781     0.3916      1.022         13        640: 100% ━━━━━━━━━━━━ 148/148 4.3it/s 34.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 6.8it/s 2.8s0.1s
#                    all        221        221       0.97          1      0.993      0.897       0.97          1      0.993      0.873
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      6.74G     0.3669     0.4982     0.2537     0.3506      0.976         12        640: 100% ━━━━━━━━━━━━ 148/148 4.3it/s 34.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 6.9it/s 2.8s0.1s
#                    all        221        221      0.999          1      0.995       0.97      0.999          1      0.995      0.905
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      6.73G     0.2681     0.4107     0.2329     0.2813     0.9385         14        640: 100% ━━━━━━━━━━━━ 148/148 4.3it/s 34.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 6.9it/s 2.8s0.1s
#                    all        221        221      0.989          1      0.995      0.966      0.989          1      0.995      0.894
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      6.73G     0.2298     0.4061     0.2262     0.2465     0.9165         14        640: 100% ━━━━━━━━━━━━ 148/148 4.3it/s 34.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.4it/s 2.6s0.1s
#                    all        221        221      0.999          1      0.995      0.995      0.999          1      0.995      0.896
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        7/20
1      0.995      0.988
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      6.62G    0.05318     0.1477    0.03656    0.06768     0.8364          4        640: 100% ━━━━━━━━━━━━ 148/148 4.6it/s 32.4s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 7.8it/s 2.4s0.1s
#                    all        221        221          1          1      0.995      0.995          1          1      0.995      0.985
#
# 20 epochs completed in 0.218 hours.
# Optimizer stripped from C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_5\weights\last.pt, 118.2MB
# Optimizer stripped from C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_5\weights\best.pt, 118.2MB
#
# Validating C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_5\weights\best.pt...
# Ultralytics 8.3.221  Python-3.12.6 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# YOLO11x-pose summary (fused): 199 layers, 58,739,959 parameters, 0 gradients, 202.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 6.5it/s 2.9s0.1s
#                    all        221        221          1          1      0.995      0.995          1          1      0.995      0.988
# Speed: 0.3ms preprocess, 5.6ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to C:\Users\usuario\Desktop\salmons_pose_project\runs\cv_pose\fold_5
# Ultralytics 8.3.221  Python-3.12.6 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# YOLO11x-pose summary (fused): 199 layers, 58,739,959 parameters, 0 gradients, 202.7 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 1453.2473.7 MB/s, size: 158.5 KB)
# val: Scanning C:\Users\usuario\Desktop\salmons_pose_project\labels\fold5.cache... 221 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 221/221 110.5Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.2it/s 4.3s0.2s
#                    all        221        221          1          1      0.995      0.995          1          1      0.995      0.989
# Speed: 1.2ms preprocess, 10.4ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to C:\Users\usuario\Desktop\salmons_pose_project\runs\pose\val10
# Resultados Fold 5: mAP50-95 = 0.9885
#
# RESULTADOS CROSS-VALIDATION
# Fold 1: 0.9813
# Fold 2: 0.9893
# Fold 3: 0.9884
# Fold 4: 0.9830
# Fold 5: 0.9885
# --------------------------
# PROMEDIO mAP: 0.9861
# MEJOR MODELO: runs/cv_pose\fold_2\weights\best.pt
#
# GENERANDO ETIQUETAS PARA TEST (images/test)...
#
# Procesando 343 imágenes de test...
# Progreso test: 0/343...
# Progreso test: 10/343...
# Progreso test: 20/343...
# Progreso test: 30/343...
# Progreso test: 40/343...
# Progreso test: 50/343...
# Progreso test: 60/343...
# Progreso test: 70/343...
# Progreso test: 80/343...
# Progreso test: 90/343...
# Progreso test: 100/343...
# Progreso test: 110/343...
# Progreso test: 120/343...
# Progreso test: 130/343...
# Progreso test: 140/343...
# Progreso test: 150/343...
# Progreso test: 160/343...
# Progreso test: 170/343...
# Progreso test: 180/343...
# Progreso test: 190/343...
# Progreso test: 200/343...
# Progreso test: 210/343...
# Progreso test: 220/343...
# Progreso test: 230/343...
# Progreso test: 240/343...
# Progreso test: 250/343...
# Progreso test: 260/343...
# Progreso test: 270/343...
# Progreso test: 280/343...
# Progreso test: 290/343...
# Progreso test: 300/343...
# Progreso test: 310/343...
# Progreso test: 320/343...
# Progreso test: 330/343...
# Progreso test: 340/343...
#
# Proceso completado.
# Etiquetas TEST generadas en: labels/test_pred
